# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd "drive/MyDrive/resume_bert_v2"

# %%
# !pip install transformers
# !pip install datasets
# !pip install seqeval

# %%
# !sh create_new_data.sh
